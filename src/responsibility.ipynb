# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

pd.set_option('display.max_columns', None)

# %%
DATA_PATH = '../data/'
PASSES_DF_PATH = DATA_PATH + 'passes_df.pkl'
WYSCOUT_TO_SKILLCORNER = DATA_PATH + 'wyscout2skillcorner.csv'

# %%
def responsibility(row, max_distance=10, pass_length_factor=1.0, end_location_factor=0.5):
    
    start_x = row['location.x']
    start_y = row['location.y']
    end_x = row['pass.endLocation.x']
    end_y = row['pass.endLocation.y']
    
    player_x = row['tracking.x']
    player_y = row['tracking.y']
    
    # Vector from start to end of the pass
    pass_vector = np.array([end_x - start_x, end_y - start_y])
    # Vector from start of the pass to the player's position
    player_vector = np.array([player_x - start_x, player_y - start_y])
    
    pass_length = np.linalg.norm(pass_vector)
    
    
    if pass_length > 0:
        pass_unit_vector = pass_vector / pass_length
        projection_length = np.dot(player_vector, pass_unit_vector)
        
        # Clamp projection_length to the range [0, pass_length] to account for the endpoints of the pass
        projection_length = max(0, min(projection_length, pass_length))
        
        # Find the point on the pass closest to the player
        closest_point = np.array([start_x, start_y]) + projection_length * pass_unit_vector
        
        # Distance from player to the closest point on the pass
        distance_to_pass = np.linalg.norm(np.array([player_x, player_y]) - closest_point)
    else:
        # If the pass length is zero, set distance to the player's distance from the start point
        distance_to_pass = np.linalg.norm(np.array([player_x, player_y]) - np.array([start_x, start_y]))
    
    # Calculate distance from the player to the end location of the pass
    distance_to_end_location = np.linalg.norm(np.array([player_x, player_y]) - np.array([end_x, end_y]))
    
    # Calculate responsibility with pass length and distance to pass scaling
    if distance_to_pass < max_distance and row['tracking.object_id'] != -1:
        """
        # Apply scaling based on the distance to the pass and pass length
        raw_responsibility = (1 - (distance_to_pass / max_distance)) * np.power(1 + pass_length_factor, pass_length)
        
        # Normalize the responsibility to be between 0 and 1
        max_possible_responsibility = np.power(1 + pass_length_factor, pass_length)
        responsibility_score = raw_responsibility / max_possible_responsibility
        
        # Adjust the responsibility based on the distance to the end location
        
        proximity_to_end = 1 - (distance_to_end_location / max_distance)
        end_location_adjustment = (1 + end_location_factor * proximity_to_end)
        responsibility_score *= end_location_adjustment
        """
        raw_responsibility = (1 - (distance_to_pass / max_distance)) * np.power(1 + pass_length_factor, pass_length)
        
        # Normalize the responsibility to be between 0 and 1
        max_possible_responsibility = np.power(1 + pass_length_factor, pass_length)
        responsibility_score = raw_responsibility / max_possible_responsibility
        
        
    else:
        # If the player is too far, they get no responsibility
        responsibility_score = 0
        
    
        
    return responsibility_score

# %%
passes_df = pd.read_pickle(PASSES_DF_PATH)

# %%
passes_df['responsibility'] = passes_df.apply(responsibility, axis=1, pass_length_factor = 1)

cols_to_display = ['player.id', 'tracking.object_id', 'location.x', 'location.y', 'pass.endLocation.x', 
                   'pass.endLocation.y','tracking.x', 'tracking.y', 'responsibility', 'dxt']
passes_df[cols_to_display].head(23)
# Out:
#     player.id  tracking.object_id  location.x  location.y  pass.endLocation.x  \
# 0         118                7604          51          50                  42
# 1         118               16320          51          50                  42
# 2         118               11516          51          50                  42
# 3         118               11630          51          50                  42
# 4         118               11606          51          50                  42
# 5         118               12218          51          50                  42
# 6         118                 277          51          50                  42
# 7         118                 946          51          50                  42
# 8         118                5922          51          50                  42
# 9         118                6028          51          50                  42
# 10        118               12190          51          50                  42
# 11        118                4777          51          50                  42
# 12        118               14407          51          50                  42
# 13        118               10738          51          50                  42
# 14        118               24466          51          50                  42
# 15        118                7863          51          50                  42
# 16        118               33512          51          50                  42
# 17        118                7017          51          50                  42
# 18        118                3837          51          50                  42
# 19        118               10082          51          50                  42
# 20        118               31930          51          50                  42
# 21        118                7387          51          50                  42
# 22        625                7604          42          83                  29
#
#     pass.endLocation.y  tracking.x  tracking.y  responsibility       dxt
# 0                   83      -41.03       -0.05             0.0 -0.004162
# 1                   83      -15.86       -7.61             0.0 -0.004162
# 2                   83      -16.08        2.42             0.0 -0.004162
# 3                   83      -14.54      -18.87             0.0 -0.004162
# 4                   83      -14.08       17.56             0.0 -0.004162
# 5                   83       -9.69        0.05             0.0 -0.004162
# 6                   83       -7.61        9.58             0.0 -0.004162
# 7                   83       -6.20       -6.81             0.0 -0.004162
# 8                   83       -1.21      -19.48             0.0 -0.004162
# 9                   83       -0.19       22.92             0.0 -0.004162
# 10                  83        0.12       -9.05             0.0 -0.004162
# 11                  83       40.57        0.23             0.0 -0.004162
# 12                  83       18.81        5.97             0.0 -0.004162
# 13                  83       18.44      -12.58             0.0 -0.004162
# 14                  83       11.61       21.55             0.0 -0.004162
# 15                  83       14.46      -22.88             0.0 -0.004162
# 16                  83       11.06       -4.01             0.0 -0.004162
# 17                  83       11.04        7.53             0.0 -0.004162
# 18                  83        2.86       -8.93             0.0 -0.004162
# 19                  83        0.45       21.52             0.0 -0.004162
# 20                  83        0.35      -18.34             0.0 -0.004162
# 21                  83       -0.70        0.90             0.0 -0.004162
# 22                  60      -40.47        0.83             0.0 -0.002211

# %%
wyscout2skillcorner = pd.read_csv(WYSCOUT_TO_SKILLCORNER).drop(columns='id')

# %%
# First, merge id_map with joined_df on player.id (WyScout player IDs) to get the team_name_sk for player_skillcorner_id
passes_df = passes_df.merge(wyscout2skillcorner[['player_id_wy', 'player_id_sk', 'team_name_sk']],
                            left_on='player.id', 
                            right_on='player_id_wy', 
                            how='left')

# Rename the columns for clarity
passes_df.rename(columns={'player_id_sk': 'player_skillcorner_id', 'team_name_sk': 'team_name_skillcorner'}, inplace=True)

# Now merge id_map with object_id (which is SkillCorner ID) to get the team_name_sk for object_id
passes_df = passes_df.merge(wyscout2skillcorner[['player_id_sk', 'team_name_sk']],
                            left_on='tracking.object_id', 
                            right_on='player_id_sk', 
                            how='left')

# Rename the columns for clarity
passes_df.rename(columns={'team_name_sk': 'team_name_object'}, inplace=True) 

# Finally, create a new column to check if both players are on the same team
passes_df['same_team'] = passes_df['team_name_skillcorner'] == passes_df['team_name_object']

# You can drop any unnecessary columns if needed
passes_df.drop(columns=['player_id_wy', 'player_id_sk'], inplace=True)

# %%
passes_df.columns
# Out:
# Index(['matchId', 'matchTimestamp', 'team.id', 'team.name', 'player.id',
#        'player.name', 'opponentTeam.id', 'opponentTeam.name',
#        'pass.recipient.id', 'pass.recipient.name', 'location.x', 'location.y',
#        'pass.endLocation.x', 'pass.endLocation.y', 'dxt', 'tracking.object_id',
#        'tracking.x', 'tracking.y', 'tracking.z', 'tracking.x_norm',
#        'tracking.y_norm', 'tracking.team_name', 'tracking.player_id',
#        'tracking.player_first_name', 'tracking.player_last_name',
#        'responsibility', 'player_skillcorner_id', 'team_name_skillcorner',
#        'team_name_object', 'same_team'],
#       dtype='object')

# %%
#joined_df['same_team'] = joined_df['team.name'] == joined_df['team_name_sk_y']
cols_to_display.append('team.name')
cols_to_display.append('team_name_object')
cols_to_display.append('same_team')
passes_df[cols_to_display].head(23)
# Out:
#     player.id  tracking.object_id  location.x  location.y  pass.endLocation.x  \
# 0         118                7604          51          50                  42
# 1         118               16320          51          50                  42
# 2         118               11516          51          50                  42
# 3         118               11630          51          50                  42
# 4         118               11606          51          50                  42
# 5         118               12218          51          50                  42
# 6         118                 277          51          50                  42
# 7         118                 946          51          50                  42
# 8         118                5922          51          50                  42
# 9         118                6028          51          50                  42
# 10        118               12190          51          50                  42
# 11        118                4777          51          50                  42
# 12        118               14407          51          50                  42
# 13        118               10738          51          50                  42
# 14        118               24466          51          50                  42
# 15        118                7863          51          50                  42
# 16        118               33512          51          50                  42
# 17        118                7017          51          50                  42
# 18        118                3837          51          50                  42
# 19        118               10082          51          50                  42
# 20        118               31930          51          50                  42
# 21        118                7387          51          50                  42
# 22        625                7604          42          83                  29
#
#     pass.endLocation.y  tracking.x  tracking.y  responsibility       dxt  \
# 0                   83      -41.03       -0.05             0.0 -0.004162
# 1                   83      -15.86       -7.61             0.0 -0.004162
# 2                   83      -16.08        2.42             0.0 -0.004162
# 3                   83      -14.54      -18.87             0.0 -0.004162
# 4                   83      -14.08       17.56             0.0 -0.004162
# 5                   83       -9.69        0.05             0.0 -0.004162
# 6                   83       -7.61        9.58             0.0 -0.004162
# 7                   83       -6.20       -6.81             0.0 -0.004162
# 8                   83       -1.21      -19.48             0.0 -0.004162
# 9                   83       -0.19       22.92             0.0 -0.004162
# 10                  83        0.12       -9.05             0.0 -0.004162
# 11                  83       40.57        0.23             0.0 -0.004162
# 12                  83       18.81        5.97             0.0 -0.004162
# 13                  83       18.44      -12.58             0.0 -0.004162
# 14                  83       11.61       21.55             0.0 -0.004162
# 15                  83       14.46      -22.88             0.0 -0.004162
# 16                  83       11.06       -4.01             0.0 -0.004162
# 17                  83       11.04        7.53             0.0 -0.004162
# 18                  83        2.86       -8.93             0.0 -0.004162
# 19                  83        0.45       21.52             0.0 -0.004162
# 20                  83        0.35      -18.34             0.0 -0.004162
# 21                  83       -0.70        0.90             0.0 -0.004162
# 22                  60      -40.47        0.83             0.0 -0.002211
#
#       team.name team_name_object  same_team
# 0   Netherlands     France            False
# 1   Netherlands     France            False
# 2   Netherlands     France            False
# 3   Netherlands     France            False
# 4   Netherlands     France            False
# 5   Netherlands     France            False
# 6   Netherlands     France            False
# 7   Netherlands     France            False
# 8   Netherlands     France            False
# 9   Netherlands     France            False
# 10  Netherlands     France            False
# 11  Netherlands     Netherland         True
# 12  Netherlands     Netherland         True
# 13  Netherlands     Netherland         True
# 14  Netherlands     Netherland         True
# 15  Netherlands     Netherland         True
# 16  Netherlands     Netherland         True
# 17  Netherlands     Netherland         True
# 18  Netherlands     Netherland         True
# 19  Netherlands     Netherland         True
# 20  Netherlands     Netherland         True
# 21  Netherlands     Netherland         True
# 22  Netherlands     France            False

# %%
passes_df['responsibility'] = np.where(passes_df['same_team'], 0, passes_df['responsibility'])
passes_df.head(23)
# Out:
#     matchId matchTimestamp  team.id    team.name  player.id player.name  \
# 0   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 1   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 2   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 3   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 4   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 5   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 6   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 7   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 8   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 9   5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 10  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 11  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 12  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 13  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 14  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 15  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 16  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 17  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 18  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 19  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 20  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 21  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 22  5414111   00:00:05.782      664  Netherlands        625  M. de Roon
#
#     opponentTeam.id opponentTeam.name  pass.recipient.id pass.recipient.name  \
# 0              4418            France                625          M. de Roon
# 1              4418            France                625          M. de Roon
# 2              4418            France                625          M. de Roon
# 3              4418            France                625          M. de Roon
# 4              4418            France                625          M. de Roon
# 5              4418            France                625          M. de Roon
# 6              4418            France                625          M. de Roon
# 7              4418            France                625          M. de Roon
# 8              4418            France                625          M. de Roon
# 9              4418            France                625          M. de Roon
# 10             4418            France                625          M. de Roon
# 11             4418            France                625          M. de Roon
# 12             4418            France                625          M. de Roon
# 13             4418            France                625          M. de Roon
# 14             4418            France                625          M. de Roon
# 15             4418            France                625          M. de Roon
# 16             4418            France                625          M. de Roon
# 17             4418            France                625          M. de Roon
# 18             4418            France                625          M. de Roon
# 19             4418            France                625          M. de Roon
# 20             4418            France                625          M. de Roon
# 21             4418            France                625          M. de Roon
# 22             4418            France             476361       L. Geertruida
#
#     location.x  location.y  pass.endLocation.x  pass.endLocation.y       dxt  \
# 0           51          50                  42                  83 -0.004162
# 1           51          50                  42                  83 -0.004162
# 2           51          50                  42                  83 -0.004162
# 3           51          50                  42                  83 -0.004162
# 4           51          50                  42                  83 -0.004162
# 5           51          50                  42                  83 -0.004162
# 6           51          50                  42                  83 -0.004162
# 7           51          50                  42                  83 -0.004162
# 8           51          50                  42                  83 -0.004162
# 9           51          50                  42                  83 -0.004162
# 10          51          50                  42                  83 -0.004162
# 11          51          50                  42                  83 -0.004162
# 12          51          50                  42                  83 -0.004162
# 13          51          50                  42                  83 -0.004162
# 14          51          50                  42                  83 -0.004162
# 15          51          50                  42                  83 -0.004162
# 16          51          50                  42                  83 -0.004162
# 17          51          50                  42                  83 -0.004162
# 18          51          50                  42                  83 -0.004162
# 19          51          50                  42                  83 -0.004162
# 20          51          50                  42                  83 -0.004162
# 21          51          50                  42                  83 -0.004162
# 22          42          83                  29                  60 -0.002211
#
#     tracking.object_id  tracking.x  tracking.y  tracking.z  tracking.x_norm  \
# 0                 7604      -41.03       -0.05         0.0        89.076190
# 1                16320      -15.86       -7.61         0.0        65.104762
# 2                11516      -16.08        2.42         0.0        65.314286
# 3                11630      -14.54      -18.87         0.0        63.847619
# 4                11606      -14.08       17.56         0.0        63.409524
# 5                12218       -9.69        0.05         0.0        59.228571
# 6                  277       -7.61        9.58         0.0        57.247619
# 7                  946       -6.20       -6.81         0.0        55.904762
# 8                 5922       -1.21      -19.48         0.0        51.152381
# 9                 6028       -0.19       22.92         0.0        50.180952
# 10               12190        0.12       -9.05         0.0        49.885714
# 11                4777       40.57        0.23         0.0        11.361905
# 12               14407       18.81        5.97         0.0        32.085714
# 13               10738       18.44      -12.58         0.0        32.438095
# 14               24466       11.61       21.55         0.0        38.942857
# 15                7863       14.46      -22.88         0.0        36.228571
# 16               33512       11.06       -4.01         0.0        39.466667
# 17                7017       11.04        7.53         0.0        39.485714
# 18                3837        2.86       -8.93         0.0        47.276190
# 19               10082        0.45       21.52         0.0        49.571429
# 20               31930        0.35      -18.34         0.0        49.666667
# 21                7387       -0.70        0.90         0.0        50.666667
# 22                7604      -40.47        0.83         0.0        88.542857
#
#     tracking.y_norm tracking.team_name  tracking.player_id  \
# 0         49.926471             France                7604
# 1         38.808824             France               16320
# 2         53.558824             France               11516
# 3         22.250000             France               11630
# 4         75.823529             France               11606
# 5         50.073529             France               12218
# 6         64.088235             France                 277
# 7         39.985294             France                 946
# 8         21.352941             France                5922
# 9         83.705882             France                6028
# 10        36.691176             France               12190
# 11        50.338235         Netherland                4777
# 12        58.779412         Netherland               14407
# 13        31.500000         Netherland               10738
# 14        81.691176         Netherland               24466
# 15        16.352941         Netherland                7863
# 16        44.102941         Netherland               33512
# 17        61.073529         Netherland                7017
# 18        36.867647         Netherland                3837
# 19        81.647059         Netherland               10082
# 20        23.029412         Netherland               31930
# 21        51.323529         Netherland                7387
# 22        51.220588             France                7604
#
#    tracking.player_first_name tracking.player_last_name  responsibility  \
# 0                        Mike                   Maignan             0.0
# 1                    Ibrahima                    Konaté             0.0
# 2                       Dayot                 Upamecano             0.0
# 3                       Jules                    Koundé             0.0
# 4                        Theo                 Hernández             0.0
# 5                    Aurélien                Tchouaméni             0.0
# 6                      Adrien                    Rabiot             0.0
# 7                     Antoine                 Griezmann             0.0
# 8                    Kingsley                     Coman             0.0
# 9                      Kylian             Mbappé Lottin             0.0
# 10                     Randal                Kolo Muani             0.0
# 11                     Jasper                 Cillessen             0.0
# 12                  Lutsharel                Geertruida             0.0
# 13                     Virgil                  van Dijk             0.0
# 14                    Jurriën             Timber Maduro             0.0
# 15                     Nathan                       Aké             0.0
# 16                    Kenneth                    Taylor             0.0
# 17                     Marten                   de Roon             0.0
# 18                  Georginio                 Wijnaldum             0.0
# 19                     Steven                  Berghuis             0.0
# 20          Xavi Quentin Shay                    Simons             0.0
# 21                    Memphis                     Depay             0.0
# 22                       Mike                   Maignan             0.0
#
#     player_skillcorner_id team_name_skillcorner team_name_object  same_team
# 0                    7387          Netherland       France            False
# 1                    7387          Netherland       France            False
# 2                    7387          Netherland       France            False
# 3                    7387          Netherland       France            False
# 4                    7387          Netherland       France            False
# 5                    7387          Netherland       France            False
# 6                    7387          Netherland       France            False
# 7                    7387          Netherland       France            False
# 8                    7387          Netherland       France            False
# 9                    7387          Netherland       France            False
# 10                   7387          Netherland       France            False
# 11                   7387          Netherland       Netherland         True
# 12                   7387          Netherland       Netherland         True
# 13                   7387          Netherland       Netherland         True
# 14                   7387          Netherland       Netherland         True
# 15                   7387          Netherland       Netherland         True
# 16                   7387          Netherland       Netherland         True
# 17                   7387          Netherland       Netherland         True
# 18                   7387          Netherland       Netherland         True
# 19                   7387          Netherland       Netherland         True
# 20                   7387          Netherland       Netherland         True
# 21                   7387          Netherland       Netherland         True
# 22                   7017          Netherland       France            False

# %%
passes_df
# Out:
#        matchId matchTimestamp  team.id    team.name  player.id player.name  \
# 0      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 1      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 2      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 3      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 4      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# ...        ...            ...      ...          ...        ...         ...
# 19707  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19708  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19709  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19710  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19711  5414111   01:33:38.826      664  Netherlands        118    M. Depay
#
#        opponentTeam.id opponentTeam.name  pass.recipient.id  \
# 0                 4418            France                625
# 1                 4418            France                625
# 2                 4418            France                625
# 3                 4418            France                625
# 4                 4418            France                625
# ...                ...               ...                ...
# 19707             4418            France             221069
# 19708             4418            France             221069
# 19709             4418            France             221069
# 19710             4418            France             221069
# 19711             4418            France             221069
#
#       pass.recipient.name  location.x  location.y  pass.endLocation.x  \
# 0              M. de Roon          51          50                  42
# 1              M. de Roon          51          50                  42
# 2              M. de Roon          51          50                  42
# 3              M. de Roon          51          50                  42
# 4              M. de Roon          51          50                  42
# ...                   ...         ...         ...                 ...
# 19707         W. Weghorst          80          17                  89
# 19708         W. Weghorst          80          17                  89
# 19709         W. Weghorst          80          17                  89
# 19710         W. Weghorst          80          17                  89
# 19711         W. Weghorst          80          17                  89
#
#        pass.endLocation.y       dxt  tracking.object_id  tracking.x  \
# 0                      83 -0.004162                7604      -41.03
# 1                      83 -0.004162               16320      -15.86
# 2                      83 -0.004162               11516      -16.08
# 3                      83 -0.004162               11630      -14.54
# 4                      83 -0.004162               11606      -14.08
# ...                   ...       ...                 ...         ...
# 19707                  42  0.064346               20191       31.49
# 19708                  42  0.064346               12229       31.89
# 19709                  42  0.064346               12246       35.56
# 19710                  42  0.064346                6028        5.09
# 19711                  42  0.064346                8206        2.10
#
#        tracking.y  tracking.z  tracking.x_norm  tracking.y_norm  \
# 0           -0.05         0.0        89.076190        49.926471
# 1           -7.61         0.0        65.104762        38.808824
# 2            2.42         0.0        65.314286        53.558824
# 3          -18.87         0.0        63.847619        22.250000
# 4           17.56         0.0        63.409524        75.823529
# ...           ...         ...              ...              ...
# 19707       -1.03         0.0        20.009524        48.485294
# 19708        8.13         0.0        19.628571        61.955882
# 19709       12.33         0.0        16.133333        68.132353
# 19710       -7.70         0.0        45.152381        38.676471
# 19711      -16.52         0.0        48.000000        25.705882
#
#       tracking.team_name  tracking.player_id tracking.player_first_name  \
# 0                 France                7604                       Mike
# 1                 France               16320                   Ibrahima
# 2                 France               11516                      Dayot
# 3                 France               11630                      Jules
# 4                 France               11606                       Theo
# ...                  ...                 ...                        ...
# 19707             France               20191                   Khéphren
# 19708             France               12229                   Youssouf
# 19709             France               12246                     Moussa
# 19710             France                6028                     Kylian
# 19711             France                8206                    Olivier
#
#       tracking.player_last_name  responsibility  player_skillcorner_id  \
# 0                       Maignan             0.0                   7387
# 1                        Konaté             0.0                   7387
# 2                     Upamecano             0.0                   7387
# 3                        Koundé             0.0                   7387
# 4                     Hernández             0.0                   7387
# ...                         ...             ...                    ...
# 19707              Thuram-Ulien             0.0                   7387
# 19708                    Fofana             0.0                   7387
# 19709                     Diaby             0.0                   7387
# 19710             Mbappé Lottin             0.0                   7387
# 19711                    Giroud             0.0                   7387
#
#       team_name_skillcorner team_name_object  same_team
# 0              Netherland       France            False
# 1              Netherland       France            False
# 2              Netherland       France            False
# 3              Netherland       France            False
# 4              Netherland       France            False
# ...                     ...              ...        ...
# 19707          Netherland       France            False
# 19708          Netherland       France            False
# 19709          Netherland       France            False
# 19710          Netherland       France            False
# 19711          Netherland       France            False
#
# [19712 rows x 30 columns]
