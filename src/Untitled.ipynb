# %%
#import numpy as np
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/keremgura/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/keremgura/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/keremgura/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
# ...

# %%
data = pd.read_csv('responsibility.csv')
data
# Out:
#              timestamp  period  matchId matchTimestamp  team.id    team.name  \
# 0      00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 1      00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 2      00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 3      00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 4      00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# ...                ...     ...      ...            ...      ...          ...
# 20603  01:33:38.800000       2  5414111   01:33:38.826      664  Netherlands
# 20604  01:33:38.800000       2  5414111   01:33:38.826      664  Netherlands
# 20605  01:33:38.800000       2  5414111   01:33:38.826      664  Netherlands
# 20606  01:33:38.800000       2  5414111   01:33:38.826      664  Netherlands
# 20607  01:33:38.800000       2  5414111   01:33:38.826      664  Netherlands
#
# ...

# %%
id_map = pd.read_csv('player_id_map.csv')
id_map
# Out:
#     Unnamed: 0  player_id_sk player_first_name_sk player_last_name_sk  \
# 0            0           277               Adrien              Rabiot
# 1            1           946              Antoine           Griezmann
# 2            2         12218             Aurélien          Tchouaméni
# 3            3          2106                Daley               Blind
# 4            4          2548                 Davy            Klaassen
# 5            5         11516                Dayot           Upamecano
# 6            6         12654              Donyell               Malen
# 7            7         22103              Eduardo           Camavinga
# 8            8          3837            Georginio           Wijnaldum
# 9            9         16320             Ibrahima              Konaté
# 10          10          4777               Jasper           Cillessen
# 11          11         11630                Jules              Koundé
# ...

# %%
data.head(22)
# Out:
#           timestamp  period  matchId matchTimestamp  team.id    team.name  \
# 0   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 1   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 2   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 3   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 4   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 5   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 6   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 7   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 8   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 9   00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 10  00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# 11  00:00:01.900000       1  5414111   00:00:01.912      664  Netherlands
# ...
