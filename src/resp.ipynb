# %%
import pandas as pd
import json
import zipfile
import os
from datetime import datetime, timedelta

pd.set_option('display.max_columns', None)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/keremgura/anaconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/keremgura/anaconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/keremgura/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
# ...

# %%
DATA_PATH = '../data/'
WYSCOUT_PATH = DATA_PATH + 'wyscout/'
SKILLCORNER_PATH = DATA_PATH + 'skillcorner/'
XT_PLOT_PATH = DATA_PATH + 'xt_plot_worldcup.csv'
MATCH_IDS_PATH = DATA_PATH + 'matchids.csv'

# %% [markdown]
# ## Load Data

# %%
def unzip_all_files_in_dir(directory, target_directory):
    for file in os.listdir(directory):
        if file.endswith('.zip'):
            with zipfile.ZipFile(directory + file, 'r') as zip_ref:
                zip_ref.extractall(target_directory)

# %%
unzip = False

if unzip:
    unzip_all_files_in_dir('../../soccer-analytics/data/wyscout/', WYSCOUT_PATH)
    unzip_all_files_in_dir('../../soccer-analytics/data/skillcorner/', SKILLCORNER_PATH)

# %%
match_info = pd.read_csv(MATCH_IDS_PATH)
match_info = match_info.dropna(subset=['wyscout', 'skillcorner'])
match_info['skillcorner'] = match_info['skillcorner'].astype(int)

# %%
match_info.head(5)
# Out:
#     wyscout  skillcorner        date                 home result         away
# 8   5414111       952209  2023-03-24               France    4-0  Netherlands
# 10  5414113       726849  2023-03-24       Czech Republic    3-1       Poland
# 12  5414115       722109  2023-03-24               Sweden    0-3      Belgium
# 25  5414127       726848  2023-03-26              England    2-0      Ukraine
# 33  5414135       952208  2023-03-27  Republic of Ireland    0-1       France

# %%
wyscout_id = match_info['wyscout'].values[0]
skillcorner_id = match_info['skillcorner'].values[0]

# %%
import utils

# %%
utils
# Out:
# <module 'utils' from '/Users/keremgura/Library/CloudStorage/OneDrive-Personal/ETH Zürich/Semesters/Fall24/DS Lab/dsl-hs-2024/src/utils.py'>

# %%
def wyscout_to_df(filepath, lines=False):
    with open(filepath, encoding='utf8') as f:
        js = json.load(f)
    df = pd.json_normalize(js['events'])
    return df

# %% [markdown]
# ### wyscout

# %%
wyscout_data = wyscout_to_df(WYSCOUT_PATH + str(wyscout_id) + ".json")
with pd.option_context('display.max_columns', None):
    display(wyscout_data.head(3))
# Out:
#            id  matchId matchPeriod  minute  second matchTimestamp  \
# 0  1587492614  5414111          1H       0       1   00:00:01.912
# 1  1587492615  5414111          1H       0       5   00:00:05.782
# 2  1587492616  5414111          1H       0       8   00:00:08.951
#
#   videoTimestamp  relatedEventId  shot  groundDuel  aerialDuel  infraction  \
# 0       3.912638    1.587493e+09   NaN         NaN         NaN         NaN
# 1       7.782226    1.587493e+09   NaN         NaN         NaN         NaN
# 2      10.951834    1.587493e+09   NaN         NaN         NaN         NaN
#
#    carry type.primary                        type.secondary  location.x  \
# 0    NaN         pass  [lateral_pass, short_or_medium_pass]          51
# 1    NaN         pass  [lateral_pass, short_or_medium_pass]          42
# 2    NaN         pass  [lateral_pass, short_or_medium_pass]          29
#
#    location.y  team.id    team.name team.formation  opponentTeam.id  \
# ...

# %% [markdown]
# ### skillcorner

# %%
metadata = pd.read_csv(SKILLCORNER_PATH + str(skillcorner_id) + "_metadata.csv")
tracking_df = pd.read_csv(SKILLCORNER_PATH + str(skillcorner_id) + "_tracking.csv")
lineup_df = pd.read_csv(SKILLCORNER_PATH + str(skillcorner_id) + "_lineup.csv")

# %%
print("Metadata")
display(metadata.head(3))
print("Tracking")
display(tracking_df.head(3))
print("Lineup")
display(lineup_df.head(3))
# Out:
# Metadata
#    match_id        match_date                       competition     season  \
# 0    952209  03/24/2023 19:45  European Championship Qualifiers  2023/2024
#
#   home_team   away_team  home_score  away_score home_team_jersey_color  \
# 0    France  Netherland           4           0                #fafafa
#
#   away_team_jersey_color home_team_number_color away_team_number_color  \
# 0                #ff824c                #000000                #000000
#
#     home_team_coach away_team_coach       pitch_name  pitch_length  \
# 0  Didier Deschamps   Frank De Boer  Stade de France         105.0
#
#    pitch_width     provider  fps
# 0         68.0  SkillCorner   10
# Tracking
#    match_id  half  frame_id  timestamp  object_id      x     y     z  \
# 0    952209     1        20          0         -1   0.12 -0.19  0.12
# 1    952209     1        20          0       7604 -39.44 -0.21  0.00
# 2    952209     1        20          0      16320 -16.05 -7.18  0.00
#
# ...

# %% [markdown]
# # Pass Events

# %%
passes_df = wyscout_data[wyscout_data['type.primary'] == 'pass']

# Filter out inaccurate passes
accurate_only = True
if accurate_only:
    passes_df = passes_df[passes_df['pass.accurate'] == True]

print(passes_df.shape)
# Out:
# (897, 93)

# %%
relevant_columns = ['id', 'matchId', 'matchPeriod', 'matchTimestamp',
       'relatedEventId', 'type.primary', 'type.secondary', 'location.x',
       'location.y', 'team.id', 'team.name', 'opponentTeam.id', 'opponentTeam.name', 'player.id', 'player.name', 'player.position', 'pass.accurate',
       'pass.angle', 'pass.height', 'pass.length', 'pass.recipient.id',
       'pass.recipient.name', 'pass.recipient.position', 'pass.endLocation.x',
       'pass.endLocation.y', 'possession.id', 'possession.attack.withShotOnGoal', 'possession.attack.withGoal']
passes_ext = passes_df[relevant_columns]

print(passes_ext.shape)
# Out:
# (897, 28)

# %%
passes = passes_df.loc[:,['matchId', 'matchTimestamp', 'matchPeriod', 'team.id', 'team.name', 'player.id', 'player.name', 'opponentTeam.id', 'opponentTeam.name', 'pass.recipient.id', 'pass.recipient.name', 'location.x', 'location.y', 'pass.endLocation.x', 'pass.endLocation.y']]
passes.head()
# Out:
#    matchId matchTimestamp matchPeriod  team.id    team.name  player.id  \
# 0  5414111   00:00:01.912          1H      664  Netherlands        118
# 1  5414111   00:00:05.782          1H      664  Netherlands        625
# 2  5414111   00:00:08.951          1H      664  Netherlands     476361
# 3  5414111   00:00:13.151          1H      664  Netherlands        370
# 5  5414111   00:00:17.930          1H      664  Netherlands     476361
#
#      player.name  opponentTeam.id opponentTeam.name  pass.recipient.id  \
# 0       M. Depay             4418            France              625.0
# 1     M. de Roon             4418            France           476361.0
# 2  L. Geertruida             4418            France              370.0
# 3    V. van Dijk             4418            France           476361.0
# 5  L. Geertruida             4418            France              370.0
#
#   pass.recipient.name  location.x  location.y  pass.endLocation.x  \
# ...

# %%
passes['matchPeriod'] = passes['matchPeriod'].apply(lambda x: int(x.split('H')[0]))
passes['pass.recipient.id'] = passes['pass.recipient.id'].astype(int)
passes['pass.endLocation.x'] = passes['pass.endLocation.x'].astype(int)
passes['pass.endLocation.y'] = passes['pass.endLocation.y'].astype(int)

# %%
passes.head()
# Out:
#    matchId matchTimestamp  matchPeriod  team.id    team.name  player.id  \
# 0  5414111   00:00:01.912            1      664  Netherlands        118
# 1  5414111   00:00:05.782            1      664  Netherlands        625
# 2  5414111   00:00:08.951            1      664  Netherlands     476361
# 3  5414111   00:00:13.151            1      664  Netherlands        370
# 5  5414111   00:00:17.930            1      664  Netherlands     476361
#
#      player.name  opponentTeam.id opponentTeam.name  pass.recipient.id  \
# 0       M. Depay             4418            France                625
# 1     M. de Roon             4418            France             476361
# 2  L. Geertruida             4418            France                370
# 3    V. van Dijk             4418            France             476361
# 5  L. Geertruida             4418            France                370
#
#   pass.recipient.name  location.x  location.y  pass.endLocation.x  \
# ...

# %% [markdown]
# # Compute ΔxT

# %%
xt_table = pd.read_csv('../data/xt_plot_worldcup.csv')
xt_table = pd.read_csv('../data/smoothed_xt.csv')

# %% [markdown]
# In wyscout coordinates are normalized to the range (0,100) in both spatial dimensions.

# %%
cell_width = 100 / xt_table.shape[1]
cell_height = 100 / xt_table.shape[0]

print(f'cell width:\t{round(cell_width,2)}')
print(f'cell height:\t{round(cell_height,2)}')
# Out:
# cell width:	0.95
# cell height:	1.47

# %%
def get_xt_index(x, y):
    x_index = min(int(x // cell_width), xt_table.shape[1] - 1)
    y_index = min(int(y // cell_height), xt_table.shape[0] - 1)
    return x_index, y_index

# %%
start_xts = passes.apply(lambda row: xt_table.iat[get_xt_index(row['location.x'], row['location.y'])[1], 
                                                           get_xt_index(row['location.x'], row['location.y'])[0]], axis=1)
end_xts = passes.apply(lambda row: xt_table.iat[get_xt_index(row['pass.endLocation.x'], row['pass.endLocation.y'])[1], 
                                                         get_xt_index(row['pass.endLocation.x'], row['pass.endLocation.y'])[0]], axis=1)
passes.loc[:,'dxt'] = end_xts - start_xts

# %% [markdown]
# # Player Locations

# %%
def round_to_tenth_of_second(timestamp):
    dt = datetime.strptime(timestamp, '%H:%M:%S.%f')
    microsecond = dt.microsecond
    rounded_microsecond = round(microsecond, -5)
    if rounded_microsecond == 1000000:
        dt += timedelta(seconds=1)
        rounded_microsecond = 0
    dt = dt.replace(microsecond=rounded_microsecond)
    return f"{dt.strftime('%H:%M:%S')}.{rounded_microsecond:06}"

def convert_timestamp(row):
    ts = row['timestamp']
    if row['half'] == 2:
        ts += 45 * 60 * 1000  # Add 45 minutes in milliseconds
    td = timedelta(milliseconds=ts)
    total_seconds = int(td.total_seconds())
    microseconds = int(td.microseconds)
    return f"{total_seconds // 3600:02}:{(total_seconds % 3600) // 60:02}:{total_seconds % 60:02}.{microseconds:06}"

# %%
columns_to_drop = ['frame_id', 'extrapolated']
existing_columns_to_drop = [col for col in columns_to_drop if col in tracking_df.columns]
tracking_df.drop(columns=existing_columns_to_drop, inplace=True)

# %%
if not {'timestamp', 'period'}.issubset(tracking_df.index.names):    
    tracking_df['timestamp'] = tracking_df.apply(convert_timestamp, axis=1)
    tracking_df.set_index(['timestamp', 'half'], inplace=True)
    tracking_df.rename_axis(index={'timestamp': 'timestamp', 'half': 'period'}, inplace=True)
tracking_df.sample(3)
# Out:
#                         match_id  object_id      x      y     z
# timestamp       period
# 00:00:10.600000 1         952209         -1  25.43 -17.53  0.07
# 01:18:39.500000 2         952209       7604  36.74  -6.18  0.00
# 01:17:08.100000 2         952209      10738 -26.86  22.90  0.00

# %%
passes['quantizedTimestamp'] = passes['matchTimestamp'].apply(round_to_tenth_of_second)
if not {'timestamp', 'period'}.issubset(passes.index.names):
    passes.set_index(['quantizedTimestamp', 'matchPeriod'], inplace=True)
    passes.rename_axis(index={'quantizedTimestamp': 'timestamp', 'matchPeriod': 'period'}, inplace=True)

# %%
joined_df = passes.join(tracking_df, how='inner')

# %%
columns_to_drop = ['match_id']
existing_columns_to_drop = [col for col in columns_to_drop if col in joined_df.columns]
joined_df.drop(columns=existing_columns_to_drop, inplace=True)

joined_df['object_id'] = joined_df['object_id'].astype(int)

# %% [markdown]
# # Normalize Pitch Coordinates

# %%
pitch_length = metadata['pitch_length'].values[0]
pitch_width = metadata['pitch_width'].values[0]

# %%
def normalize_coordinates(row):
    x, y = row['x'], row['y']
    new_x = (-x + pitch_length/2) / pitch_length * 100
    new_y = (y + pitch_width/2) / pitch_width * 100
    return new_x, new_y

# %%
df = joined_df.apply(lambda row: normalize_coordinates(row), axis=1)
joined_df[['x_norm', 'y_norm']] = pd.DataFrame(df.tolist(), index=df.index)

# %% [markdown]
# # Identify Attackers and Defenders

# %%
lineup_df_filt = lineup_df[['team_name', 'player_id', 'player_first_name', 'player_last_name']]

joined_df = joined_df.merge(lineup_df_filt, left_on='object_id', right_on='player_id')

# %%
columns_to_prefix = ['object_id', 'x', 'y', 'z', 'x_norm', 'y_norm', 'team_name', 'player_id' ,'player_first_name', 'player_last_name']
prefix = 'tracking.'
joined_df.rename(columns={col: prefix + col for col in columns_to_prefix}, inplace=True)

# %%
# joined_df.to_pickle('passes_df.pkl')

# %%
joined_df
# Out:
#        matchId matchTimestamp  team.id    team.name  player.id player.name  \
# 0      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 1      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 2      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 3      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 4      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# ...        ...            ...      ...          ...        ...         ...
# 19707  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19708  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19709  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19710  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19711  5414111   01:33:38.826      664  Netherlands        118    M. Depay
#
#        opponentTeam.id opponentTeam.name  pass.recipient.id  \
# ...

# %% [markdown]
# # Responsibility

# %%
import numpy as np

def responsibility(row, max_distance=10, pass_length_factor=1.0, end_location_factor=0.5):
    
    start_x = row['location.x']
    start_y = row['location.y']
    end_x = row['pass.endLocation.x']
    end_y = row['pass.endLocation.y']
    
    player_x = row['tracking.x_norm']
    player_y = row['tracking.y_norm']
    
    # Vector from start to end of the pass
    pass_vector = np.array([end_x - start_x, end_y - start_y])
    # Vector from start of the pass to the player's position
    player_vector = np.array([player_x - start_x, player_y - start_y])
    
    pass_length = np.linalg.norm(pass_vector)
    
    
    if pass_length > 0:
        pass_unit_vector = pass_vector / pass_length
        projection_length = np.dot(player_vector, pass_unit_vector)
        
        # Clamp projection_length to the range [0, pass_length] to account for the endpoints of the pass
        projection_length = max(0, min(projection_length, pass_length))
        
        # Find the point on the pass closest to the player
        closest_point = np.array([start_x, start_y]) + projection_length * pass_unit_vector
        
        # Distance from player to the closest point on the pass
        distance_to_pass = np.linalg.norm(np.array([player_x, player_y]) - closest_point)
    else:
        # If the pass length is zero, set distance to the player's distance from the start point
        distance_to_pass = np.linalg.norm(np.array([player_x, player_y]) - np.array([start_x, start_y]))
    
    # Calculate distance from the player to the end location of the pass
    distance_to_end_location = np.linalg.norm(np.array([player_x, player_y]) - np.array([end_x, end_y]))
    
    # Calculate responsibility with pass length and distance to pass scaling
    if distance_to_pass < max_distance and row['tracking.object_id'] != -1:
        """
        # Apply scaling based on the distance to the pass and pass length
        raw_responsibility = (1 - (distance_to_pass / max_distance)) * np.power(1 + pass_length_factor, pass_length)
        
        # Normalize the responsibility to be between 0 and 1
        max_possible_responsibility = np.power(1 + pass_length_factor, pass_length)
        responsibility_score = raw_responsibility / max_possible_responsibility
        
        # Adjust the responsibility based on the distance to the end location
        
        proximity_to_end = 1 - (distance_to_end_location / max_distance)
        end_location_adjustment = (1 + end_location_factor * proximity_to_end)
        responsibility_score *= end_location_adjustment
        """
        raw_responsibility = (1 - (distance_to_pass / max_distance)) * np.power(1 + pass_length_factor, pass_length)
        
        # Normalize the responsibility to be between 0 and 1
        max_possible_responsibility = np.power(1 + pass_length_factor, pass_length)
        responsibility_score = raw_responsibility / max_possible_responsibility
        
        
    else:
        # If the player is too far, they get no responsibility
        responsibility_score = 0
        
    
        
    return responsibility_score

# %%
# copy before applying the function | backup
joined_df_cpy = joined_df.copy()

# %%
joined_df_cpy
# Out:
#        matchId matchTimestamp  team.id    team.name  player.id player.name  \
# 0      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 1      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 2      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 3      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 4      5414111   00:00:01.912      664  Netherlands        118    M. Depay
# ...        ...            ...      ...          ...        ...         ...
# 19707  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19708  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19709  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19710  5414111   01:33:38.826      664  Netherlands        118    M. Depay
# 19711  5414111   01:33:38.826      664  Netherlands        118    M. Depay
#
#        opponentTeam.id opponentTeam.name  pass.recipient.id  \
# ...

# %%
passes
# Out:
#                         matchId matchTimestamp  team.id    team.name  \
# timestamp       period
# 00:00:01.900000 1       5414111   00:00:01.912      664  Netherlands
# 00:00:05.800000 1       5414111   00:00:05.782      664  Netherlands
# 00:00:09.000000 1       5414111   00:00:08.951      664  Netherlands
# 00:00:13.200000 1       5414111   00:00:13.151      664  Netherlands
# 00:00:17.900000 1       5414111   00:00:17.930      664  Netherlands
# ...                         ...            ...      ...          ...
# 01:33:18.500000 2       5414111   01:33:18.517      664  Netherlands
# 01:33:23.600000 2       5414111   01:33:23.587      664  Netherlands
# 01:33:24.900000 2       5414111   01:33:24.921      664  Netherlands
# 01:33:36.200000 2       5414111   01:33:36.229      664  Netherlands
# 01:33:38.800000 2       5414111   01:33:38.826      664  Netherlands
#
#                         player.id    player.name  opponentTeam.id  \
# timestamp       period
# ...

# %%
joined_df['responsibility'] = joined_df.apply(responsibility, axis=1, pass_length_factor = 1)

cols_to_display = ['player.id', 'tracking.object_id', 'location.x', 'location.y', 'pass.endLocation.x', 
                   'pass.endLocation.y','tracking.x', 'tracking.y', 'tracking.x_norm', 'tracking.y_norm', 'responsibility', 'dxt']
# joined_df[cols_to_display].head(23)
# joined_df.head(20)

# %%
joined_df[cols_to_display].head(5)
# Out:
#    player.id  tracking.object_id  location.x  location.y  pass.endLocation.x  \
# 0        118                7604          51          50                  42
# 1        118               16320          51          50                  42
# 2        118               11516          51          50                  42
# 3        118               11630          51          50                  42
# 4        118               11606          51          50                  42
#
#    pass.endLocation.y  tracking.x  tracking.y  tracking.x_norm  \
# 0                  83      -41.03       -0.05        89.076190
# 1                  83      -15.86       -7.61        65.104762
# 2                  83      -16.08        2.42        65.314286
# 3                  83      -14.54      -18.87        63.847619
# 4                  83      -14.08       17.56        63.409524
#
#    tracking.y_norm  responsibility       dxt
# 0        49.926471             0.0 -0.004162
# ...

# %%
print(len(joined_df))
joined_df.head(5)
# Out:
# 19712
#    matchId matchTimestamp  team.id    team.name  player.id player.name  \
# 0  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 1  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 2  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 3  5414111   00:00:01.912      664  Netherlands        118    M. Depay
# 4  5414111   00:00:01.912      664  Netherlands        118    M. Depay
#
#    opponentTeam.id opponentTeam.name  pass.recipient.id pass.recipient.name  \
# 0             4418            France                625          M. de Roon
# 1             4418            France                625          M. de Roon
# 2             4418            France                625          M. de Roon
# 3             4418            France                625          M. de Roon
# 4             4418            France                625          M. de Roon
#
# ...

# %%
# pick relevant columns
columns_pick = ['matchId', 'matchTimestamp', 'team.id', 'player.id', 'pass.recipient.id', 'tracking.player_id', 'responsibility']
df_resp = joined_df[columns_pick].copy()
id_map = pd.read_csv(DATA_PATH + 'player_id_map.csv', index_col=0)


# drop responsibilities for team with succ pass

# %%
df_resp.head(5)
# Out:
#    matchId matchTimestamp  team.id  player.id  pass.recipient.id  \
# 0  5414111   00:00:01.912      664        118                625
# 1  5414111   00:00:01.912      664        118                625
# 2  5414111   00:00:01.912      664        118                625
# 3  5414111   00:00:01.912      664        118                625
# 4  5414111   00:00:01.912      664        118                625
#
#    tracking.player_id  responsibility
# 0                7604             0.0
# 1               16320             0.0
# 2               11516             0.0
# 3               11630             0.0
# 4               11606             0.0

# %%
id_map.head(5)
# Out:
#    player_id_sk player_first_name_sk player_last_name_sk team_name_sk  \
# 0           277               Adrien              Rabiot       France
# 1           946              Antoine           Griezmann       France
# 2         12218             Aurélien          Tchouaméni       France
# 3          2106                Daley               Blind   Netherland
# 4          2548                 Davy            Klaassen   Netherland
#
#    player_id_wy player_name_wy  team_id_wy team_name_wy
# 0        209117      A. Rabiot        4418       France
# 1          3682   A. Griezmann        4418       France
# 2        480145  A. Tchouaméni        4418       France
# 3            38       D. Blind         664  Netherlands
# 4            56    D. Klaassen         664  Netherlands

# %%
df_resp_matched = df_resp.merge(id_map, left_on='tracking.player_id', right_on='player_id_sk', how='left')

# check if every player has a matching id map
print(len(df_resp_matched))
print(len(df_resp))
assert len(df_resp_matched) == len(df_resp)

df_resp_matched.head(5)
# Out:
# 19712
# 19712
#    matchId matchTimestamp  team.id  player.id  pass.recipient.id  \
# 0  5414111   00:00:01.912      664        118                625
# 1  5414111   00:00:01.912      664        118                625
# 2  5414111   00:00:01.912      664        118                625
# 3  5414111   00:00:01.912      664        118                625
# 4  5414111   00:00:01.912      664        118                625
#
#    tracking.player_id  responsibility  player_id_sk player_first_name_sk  \
# 0                7604             0.0          7604                 Mike
# 1               16320             0.0         16320             Ibrahima
# 2               11516             0.0         11516                Dayot
# 3               11630             0.0         11630                Jules
# 4               11606             0.0         11606                 Theo
#
#   player_last_name_sk team_name_sk  player_id_wy player_name_wy  team_id_wy  \
# ...

# %%
# only keep resonsibilities for the other team, that defend against the pass
mask = df_resp_matched['team.id'] != df_resp_matched['team_id_wy']
df_resp_matched = df_resp_matched[mask]

df_resp_matched.head(5)
# Out:
#    matchId matchTimestamp  team.id  player.id  pass.recipient.id  \
# 0  5414111   00:00:01.912      664        118                625
# 1  5414111   00:00:01.912      664        118                625
# 2  5414111   00:00:01.912      664        118                625
# 3  5414111   00:00:01.912      664        118                625
# 4  5414111   00:00:01.912      664        118                625
#
#    tracking.player_id  responsibility  player_id_sk player_first_name_sk  \
# 0                7604             0.0          7604                 Mike
# 1               16320             0.0         16320             Ibrahima
# 2               11516             0.0         11516                Dayot
# 3               11630             0.0         11630                Jules
# 4               11606             0.0         11606                 Theo
#
#   player_last_name_sk team_name_sk  player_id_wy player_name_wy  team_id_wy  \
# ...

# %%
df_resp_matched[df_resp_matched['team.id']==4418].head(5)
# Out:
#      matchId matchTimestamp  team.id  player.id  pass.recipient.id  \
# 715  5414111   00:01:52.883     4418       3682             437490
# 716  5414111   00:01:52.883     4418       3682             437490
# 717  5414111   00:01:52.883     4418       3682             437490
# 718  5414111   00:01:52.883     4418       3682             437490
# 719  5414111   00:01:52.883     4418       3682             437490
#
#      tracking.player_id  responsibility  player_id_sk player_first_name_sk  \
# 715                4777             0.0          4777               Jasper
# 716               14407             0.0         14407            Lutsharel
# 717               10738             0.0         10738               Virgil
# 718               24466             0.0         24466              Jurriën
# 719                7863             0.0          7863               Nathan
#
#     player_last_name_sk team_name_sk  player_id_wy player_name_wy  team_id_wy  \
# ...

# %%
# keep only nonzero responsibilities
df_resp_nonzero = df_resp_matched[df_resp_matched['responsibility'] > 0]
df_resp_nonzero.head(5)

# check if each matchtimestamp has some responsibles
print(df_resp_nonzero['matchTimestamp'].nunique())
print(df_resp_matched['matchTimestamp'].nunique())

# because some responsibilities are all zero => distance to pass is too high: can be adjusted by changing the max_distance parameter in the responsibility function
assert df_resp_nonzero['matchTimestamp'].nunique() == df_resp_matched['matchTimestamp'].nunique(), "not every matchtimestamp has some responsibles"
# Out:
# 569
# 896
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[106], line 9
#       6 print(df_resp_nonzero['matchTimestamp'].nunique())
#       7 print(df_resp_matched['matchTimestamp'].nunique())
# ----> 9 assert df_resp_nonzero['matchTimestamp'].nunique() == df_resp_matched['matchTimestamp'].nunique(), "not every matchtimestamp has some responsibles"
#
# AssertionError: not every matchtimestamp has some responsibles

# %%
df_resp_nonzero.head(5)
# Out:
#     matchId matchTimestamp  team.id  player.id  pass.recipient.id  \
# 5   5414111   00:00:01.912      664        118                625
# 6   5414111   00:00:01.912      664        118                625
# 9   5414111   00:00:01.912      664        118                625
# 31  5414111   00:00:05.782      664        625             476361
# 54  5414111   00:00:08.951      664     476361                370
#
#     tracking.player_id  responsibility  player_id_sk player_first_name_sk  \
# 5                12218        0.177110         12218             Aurélien
# 6                  277        0.026566           277               Adrien
# 9                 6028        0.192158          6028               Kylian
# 31                6028        0.754799          6028               Kylian
# 54               12190        0.487188         12190               Randal
#
#    player_last_name_sk team_name_sk  player_id_wy player_name_wy  team_id_wy  \
# ...

# %% [markdown]
# ## Defender Passes Subnetwork

# %%
# pick defenders with their id

lineup_df.head(5)
# Out:
#    match_id   team_name  player_id player_first_name player_last_name  \
# 0    952209  Netherland      14397            Tyrell          Malacia
# 1    952209  Netherland      12654           Donyell            Malen
# 2    952209  Netherland       2548              Davy         Klaassen
# 3    952209  Netherland       2106             Daley            Blind
# 4    952209  Netherland      10916              Wout         Weghorst
#
#    player_shirt_number     player_position player_birthdate start_time  \
# 0                   16     Right Wing Back       1999-08-17   01:26:59
# 1                    7        Right Winger       1999-01-19   01:06:22
# 2                   14  Attacking Midfield       1993-02-21   01:06:22
# 3                   17       Left Midfield       1990-03-09   01:06:22
# 4                    9      Center Forward       1992-08-07   00:32:38
#
#   end_time  yellow_card  red_card  injured  goal  own_goal
# ...

# %%
defender_positions = ['Right Wing Back', 'Right Center Back', 'Left Center Back', 'Left Wing Back']

lineup_df['player_position'].unique()
# Out:
# array(['Right Wing Back', 'Right Winger', 'Attacking Midfield',
#        'Left Midfield', 'Center Forward', 'Right Midfield',
#        'Defensive Midfield', 'Right Forward', 'Left Center Back',
#        'Left Wing Back', 'Goalkeeper', 'Right Center Back', 'Left Winger',
#        'Left Forward'], dtype=object)

# %%
lineup_df_pos = lineup_df[['player_id', 'player_position']].rename(columns={'player_id': 'player_id_sk'})

df_resp_def = df_resp_nonzero.merge(lineup_df_pos, how='left')

# check if every player has a matching id in lineup_df
assert len(df_resp_def) == len(df_resp_nonzero)

# get only defenders
df_resp_def = df_resp_def[df_resp_def['player_position'].isin(defender_positions)]

print(len(df_resp_def))

df_resp_def.head(5)
# Out:
# 339
#     matchId matchTimestamp  team.id  player.id  pass.recipient.id  \
# 42  5414111   00:01:48.450      664     491458                704
# 43  5414111   00:01:49.796      664        704                625
# 51  5414111   00:03:25.549      664     134102                118
# 64  5414111   00:04:56.359      664     134102                370
# 69  5414111   00:05:07.310      664        370                704
#
#     tracking.player_id  responsibility  player_id_sk player_first_name_sk  \
# 42               11606        0.778865         11606                 Theo
# 43               11606        0.916579         11606                 Theo
# 51               11630        0.322520         11630                Jules
# 64               11630        0.724005         11630                Jules
# 69               11606        0.243004         11606                 Theo
#
#    player_last_name_sk team_name_sk  player_id_wy player_name_wy  team_id_wy  \
# ...

# %%
# group by for each player_id_sk
# df_resp_def[['matchTimestamp', 'player_id_sk']]
columns_subnet = ['matchTimestamp', 'responsibility', 'player_id_sk', 'player_first_name_sk', 'player_last_name_sk', 'player_position', 'team_id_wy', 'team_name_wy']
columns_subnet_group = ['player_id_sk', 'player_first_name_sk', 'player_last_name_sk', 'player_position', 'team_id_wy', 'team_name_wy']
# filter only relevant columns
df_resp_def = df_resp_def[columns_subnet]

# count number of timestamps for each player
# df_resp_def.groupby(columns_subnet).size()

# df_resp_def
df_resp_def.groupby(columns_subnet_group).size().reset_index(name='count') # groupby(columns_subnet).count('player_id_sk')
# Out:
#    player_id_sk player_first_name_sk player_last_name_sk    player_position  \
# 0          7863               Nathan                 Aké     Left Wing Back
# 1         10738               Virgil            van Dijk   Left Center Back
# 2         11516                Dayot           Upamecano   Left Center Back
# 3         11606                 Theo           Hernández     Left Wing Back
# 4         11630                Jules              Koundé    Right Wing Back
# 5         14397               Tyrell             Malacia    Right Wing Back
# 6         14407            Lutsharel          Geertruida  Right Center Back
# 7         16320             Ibrahima              Konaté  Right Center Back
# 8         24466              Jurriën       Timber Maduro    Right Wing Back
#
#    team_id_wy team_name_wy  count
# 0         664  Netherlands     54
# 1         664  Netherlands     26
# 2        4418       France     40
# 3        4418       France     57
# ...

# %%
df_resp_def_subnet = \
df_resp_def.groupby(columns_subnet_group).agg(
    average_responsibility=('responsibility', 'mean'),
    count=('matchTimestamp', 'size')
).reset_index()

df_resp_def_subnet.head(10)
# Out:
#    player_id_sk player_first_name_sk player_last_name_sk    player_position  \
# 0          7863               Nathan                 Aké     Left Wing Back
# 1         10738               Virgil            van Dijk   Left Center Back
# 2         11516                Dayot           Upamecano   Left Center Back
# 3         11606                 Theo           Hernández     Left Wing Back
# 4         11630                Jules              Koundé    Right Wing Back
# 5         14397               Tyrell             Malacia    Right Wing Back
# 6         14407            Lutsharel          Geertruida  Right Center Back
# 7         16320             Ibrahima              Konaté  Right Center Back
# 8         24466              Jurriën       Timber Maduro    Right Wing Back
#
#    team_id_wy team_name_wy  average_responsibility  count
# 0         664  Netherlands                0.534169     54
# 1         664  Netherlands                0.473666     26
# ...

# %%
df_resp_def
# Out:
#      matchTimestamp  responsibility  player_id_sk player_first_name_sk  \
# 42     00:01:48.450        0.778865         11606                 Theo
# 43     00:01:49.796        0.916579         11606                 Theo
# 51     00:03:25.549        0.322520         11630                Jules
# 64     00:04:56.359        0.724005         11630                Jules
# 69     00:05:07.310        0.243004         11606                 Theo
# ...             ...             ...           ...                  ...
# 1262   01:32:15.752        0.284086         16320             Ibrahima
# 1263   01:32:15.752        0.573040         11630                Jules
# 1266   01:32:30.605        0.028325         16320             Ibrahima
# 1278   01:33:13.577        0.819038         14397               Tyrell
# 1282   01:33:18.517        0.553531         11630                Jules
#
#      player_last_name_sk  team_id_wy    player_position
# 42             Hernández        4418     Left Wing Back
# ...

# %%
df_resp_def[df_resp_def['matchTimestamp']=='00:14:03.768']
# Out:
#     matchTimestamp  responsibility  player_id_sk player_first_name_sk  \
# 235   00:14:03.768        0.943664         11630                Jules
#
#     player_last_name_sk  player_position  team_id_wy team_name_wy
# 235              Koundé  Right Wing Back        4418       France

# %%
df_resp_def['matchTimestamp'].unique()[:10]
# Out:
# array(['00:01:48.450', '00:01:49.796', '00:03:25.549', '00:04:56.359',
#        '00:05:07.310', '00:05:13.922', '00:05:18.502', '00:05:22.136',
#        '00:05:58.444', '00:06:01.669'], dtype=object)

# %%
timestamp_list = df_resp_def['matchTimestamp'].unique()
for timestamp in timestamp_list:
    df_tmp = df_resp_def[df_resp_def['matchTimestamp']==timestamp]
    if len(df_tmp) > 1:
        break

# %%
df_tmp
# Out:
#    matchTimestamp  responsibility  player_id_sk player_first_name_sk  \
# 82   00:05:22.136        0.729394         16320             Ibrahima
# 83   00:05:22.136        0.427624         11516                Dayot
# 84   00:05:22.136        0.836364         11630                Jules
#
#    player_last_name_sk    player_position  team_id_wy team_name_wy
# 82              Konaté  Right Center Back        4418       France
# 83           Upamecano   Left Center Back        4418       France
# 84              Koundé    Right Wing Back        4418       France

# %%
# group by timestamp, remove count < 2
df_resp_def.groupby('matchTimestamp').filter(lambda x: len(x) >= 2).head(10)
# Out:
#     matchTimestamp  responsibility  player_id_sk player_first_name_sk  \
# 82    00:05:22.136        0.729394         16320             Ibrahima
# 83    00:05:22.136        0.427624         11516                Dayot
# 84    00:05:22.136        0.836364         11630                Jules
# 89    00:06:04.121        0.523634         14407            Lutsharel
# 90    00:06:04.121        0.807289         10738               Virgil
# 91    00:06:04.121        0.581520          7863               Nathan
# 114   00:08:59.228        0.486936         16320             Ibrahima
# 115   00:08:59.228        0.274500         11516                Dayot
# 116   00:08:59.228        0.333811         11606                 Theo
# 144   00:10:08.471        0.160523         16320             Ibrahima
#
#     player_last_name_sk    player_position  team_id_wy team_name_wy
# 82               Konaté  Right Center Back        4418       France
# ...

# %%
df_resp_def_group = df_resp_def.groupby('matchTimestamp').filter(lambda x: len(x) >= 2).groupby('matchTimestamp')

# %%
# return ordered playerid for indexing: order invariant
# index = f(k1, k2) = f(k2, k1) = (k_min, k_max)
def get_pair_id(player_id1, player_id2):
    if player_id1 < player_id2:
        return (player_id1, player_id2)
    else:
        return (player_id2, player_id1)
    
hash_pair = dict()

for group_name, group_df in df_resp_def_group:
    break

# %%
df_resp_def_2 = df_resp_def.groupby('matchTimestamp').filter(lambda x: len(x) >= 2)

columns_2 = ['matchTimestamp', 'player_id_sk_x', 'player_id_sk_y', 'responsibility_x', 'responsibility_y']
df_resp_def_joint = df_resp_def_2.merge(df_resp_def_2, on='matchTimestamp')[columns_2]
df_resp_def_joint.head(10)
# Out:
#   matchTimestamp  player_id_sk_x  player_id_sk_y  responsibility_x  \
# 0   00:05:22.136           16320           16320          0.729394
# 1   00:05:22.136           16320           11516          0.729394
# 2   00:05:22.136           16320           11630          0.729394
# 3   00:05:22.136           11516           16320          0.427624
# 4   00:05:22.136           11516           11516          0.427624
# 5   00:05:22.136           11516           11630          0.427624
# 6   00:05:22.136           11630           16320          0.836364
# 7   00:05:22.136           11630           11516          0.836364
# 8   00:05:22.136           11630           11630          0.836364
# 9   00:06:04.121           14407           14407          0.523634
#
#    responsibility_y
# 0          0.729394
# 1          0.427624
# 2          0.836364
# 3          0.729394
# 4          0.427624
# 5          0.836364
# 6          0.729394
# 7          0.427624
# 8          0.836364
# ...

# %%
# only keep id1<id2
df_resp_def_joint = df_resp_def_joint[df_resp_def_joint['player_id_sk_x'] < df_resp_def_joint['player_id_sk_y']]
df_resp_def_joint.head(25)
# Out:
#    matchTimestamp  player_id_sk_x  player_id_sk_y  responsibility_x  \
# 3    00:05:22.136           11516           16320          0.427624
# 5    00:05:22.136           11516           11630          0.427624
# 6    00:05:22.136           11630           16320          0.836364
# 12   00:06:04.121           10738           14407          0.807289
# 15   00:06:04.121            7863           14407          0.581520
# 16   00:06:04.121            7863           10738          0.581520
# 21   00:08:59.228           11516           16320          0.274500
# 23   00:08:59.228           11516           11606          0.274500
# 24   00:08:59.228           11606           16320          0.333811
# 29   00:10:08.471           11630           16320          0.596936
# 34   00:11:46.731           10738           14407          0.387831
# 37   00:11:46.731            7863           14407          0.292195
# 38   00:11:46.731            7863           10738          0.292195
# ...

# %%
# create joint responsibility
df_resp_def_joint['joint_resp'] = df_resp_def_joint['responsibility_x'] + df_resp_def_joint['responsibility_y']
df_resp_def_joint.head(5)
# Out:
#    matchTimestamp  player_id_sk_x  player_id_sk_y  responsibility_x  \
# 3    00:05:22.136           11516           16320          0.427624
# 5    00:05:22.136           11516           11630          0.427624
# 6    00:05:22.136           11630           16320          0.836364
# 12   00:06:04.121           10738           14407          0.807289
# 15   00:06:04.121            7863           14407          0.581520
#
#     responsibility_y  joint_resp
# 3           0.729394    1.157018
# 5           0.836364    1.263988
# 6           0.729394    1.565758
# 12          0.523634    1.330923
# 15          0.523634    1.105154

# %%
# group by player_id_sk_x, player_id_sk_y
# aggregate responsibility count
columns_joint_group = ['matchTimestamp', 'player_id_sk_x', 'player_id_sk_y', 'joint_resp']

df_resp_def_joint_group = df_resp_def_joint.groupby(['player_id_sk_x', 'player_id_sk_y']).agg(
    joint_responsibility_mean=('joint_resp', 'mean'),
    joint_responsibility_sum=('joint_resp', 'sum'),
    count=('matchTimestamp', 'size')
    ).reset_index()

df_resp_def_joint_group
# Out:
#     player_id_sk_x  player_id_sk_y  joint_responsibility_mean  \
# 0             7863           10738                   1.036280
# 1             7863           14407                   1.002586
# 2             7863           24466                   0.919625
# 3            10738           14407                   0.993295
# 4            10738           24466                   0.848094
# 5            11516           11606                   1.058497
# 6            11516           11630                   1.068575
# 7            11516           16320                   1.081537
# 8            11606           11630                   1.435983
# 9            11606           16320                   1.062989
# 10           11630           16320                   1.115697
# 11           14407           24466                   0.836696
#
#     joint_responsibility_sum  count
# 0                  15.544203     15
# 1                   4.010345      4
# 2                   5.517753      6
# ...
